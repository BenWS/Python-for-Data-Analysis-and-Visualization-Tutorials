# %%
import numpy as np
from pandas import Series, DataFrame
import pandas as pd

# %%
from pandas import read_html

# %%
url = 'https://en.wikipedia.org/wiki/List_of_all-time_NFL_win%E2%80%93loss_records'

# %%
# install beautiful soup
# install html5lib

# %%
dataframe_list = read_html(url)

# %%
dataframe_list[3]
# Out:
#         Rank                      Team  GP  Won  Lost   Pct.  \
# 0          1      New England Patriots  58   37    21  0.638
# 1          2       San Francisco 49ers  52   32    20  0.615
# 2          3         Green Bay Packers  60   36    24  0.600
# 3          4          Baltimore Ravens  27   16    11  0.593
# 4          5       Pittsburgh Steelers  62   36    26  0.581
# 5          6         Las Vegas Raiders  44   25    19  0.568
# 6          7            Dallas Cowboys  63   35    28  0.556
# 7          8            Denver Broncos  42   23    19  0.548
# 8          9  Washington Football Team  43   23    20  0.535
# 9         10         Carolina Panthers  17    9     8  0.529
# 10        11      Tampa Bay Buccaneers  19   10     9  0.526
# 11  12 (tie)       Philadelphia Eagles  46   23    23  0.500
# 12  12 (tie)      Jacksonville Jaguars  14    7     7  0.500
# 13        14           New York Giants  49   24    25  0.490
# 14        15            Miami Dolphins  41   20    21  0.488
# 15        16          Seattle Seahawks  35   17    18  0.486
# 16        17             New York Jets  25   12    13  0.480
# 17        18        Indianapolis Colts  48   23    25  0.479
# 18        19             Buffalo Bills  34   16    18  0.471
# 19        20             Chicago Bears  37   17    20  0.459
# 20        21          Los Angeles Rams  49   22    27  0.449
# 21        22         Arizona Cardinals  16    7     9  0.438
# 22        23          Tennessee Titans  39   17    22  0.436
# 23        24        New Orleans Saints  23   10    13  0.435
# 24        25        Kansas City Chiefs  35   15    20  0.429
# 25        26           Atlanta Falcons  24   10    14  0.417
# 26        27         Minnesota Vikings  51   21    30  0.412
# 27  28 (tie)      Los Angeles Chargers  30   12    18  0.400
# 28  28 (tie)            Houston Texans  10    4     6  0.400
# 29        30          Cleveland Browns  33   12    21  0.364
# 30        31             Detroit Lions  20    7    13  0.350
# 31        32        Cincinnati Bengals  19    5    14  0.263
#
#     Last playoffappearance   Division
# 0                     2019   AFC East
# 1                     2019   NFC West
# 2                     2020  NFC North
# 3                     2020  AFC North
# 4                     2020  AFC North
# 5                     2016   AFC West
# 6                     2018   NFC East
# 7                     2015   AFC West
# 8                     2020   NFC East
# 9                     2017  NFC South
# 10                    2020  NFC South
# 11                    2019   NFC East
# 12                    2017  AFC South
# 13                    2016   NFC East
# 14                    2016   AFC East
# 15                    2020   NFC West
# 16                    2010   AFC East
# 17                    2020  AFC South
# 18                    2020   AFC East
# 19                    2020  NFC North
# 20                    2020   NFC West
# 21                    2015   NFC West
# 22                    2020  AFC South
# 23                    2020  NFC South
# 24                    2020   AFC West
# 25                    2017  NFC South
# 26                    2019  NFC North
# 27                    2018   AFC West
# 28                    2019  AFC South
# 29                    2020  AFC North
# 30                    2016  NFC North
# 31                    2015  AFC North
