# %%
import pandas as pd
import numpy as np
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = randn(25)

# %%
dataset
# Out:
# array([-0.82910669,  0.85064359, -0.34727066, -1.37717911,  0.48036124,
#        -0.9112678 ,  1.09316817,  0.85651234,  0.89426495,  1.1377987 ,
#         0.20050106, -0.23696344, -0.25851789,  1.72378974,  1.88964369,
#        -1.35968775,  0.5936639 , -0.19967901, -0.49398487, -0.09681755,
#         0.62676461, -1.37536377,  0.18002473, -0.53147531,  0.52022988])

# %%
sns.rugplot(dataset)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
plt.hist(dataset, density=True, alpha=.3)
sns.rugplot(dataset)
# Out:
# <AxesSubplot:>

# %%
# TODO: Provide a description of what a Kernel Density Estimation Plot is, how it's used, etc. Same for a Probability Density Function and its relation to a Kernel Density Estimation Plot 

sns.rugplot(dataset)

x_min = dataset.min() - 10
x_max = dataset.max() + 10

x_axis = np.linspace(x_min,x_max,100)

bandwidth = (4*dataset.std()**5/3 * len(dataset))**0.2

kernel_list = []

for datapoint in dataset:
    # Create a kernal for each point and append it to the kernal list 
    kernel = stats.norm(loc=datapoint, scale=bandwidth).pdf(x_axis)

    kernel = kernel/kernel.max()
    kernel = kernel * .4

    kernel_list.append(kernel)
    plt.plot(x_axis, kernel, color='grey', alpha=.5)

plt.ylim(0,1)
# Out:
# (0.0, 1.0)

# %%
# TODO: What is the 'axis' parameter doing below?

kernel_list

arr1 = np.arange(0,50)
arr2 = np.arange(50,100)
arr3 = np.arange(0,100)



# np.sum(arr3)
# len(arr1)
# len(arr2)
np.sum([arr1,arr2])
np.sum(arr3)

sum_of_kde = np.sum(kernel_list, axis=0)

fig = plt.plot(x_axis, sum_of_kde, color='indianred')

# sns.rugplot(dataset)

# %%
x_axis
# Out:
# array([-11.37717911, -11.1421607 , -10.90714229, -10.67212387,
#        -10.43710546, -10.20208705,  -9.96706864,  -9.73205022,
#         -9.49703181,  -9.2620134 ,  -9.02699499,  -8.79197658,
#         -8.55695816,  -8.32193975,  -8.08692134,  -7.85190293,
#         -7.61688452,  -7.3818661 ,  -7.14684769,  -6.91182928,
#         -6.67681087,  -6.44179246,  -6.20677404,  -5.97175563,
#         -5.73673722,  -5.50171881,  -5.26670039,  -5.03168198,
#         -4.79666357,  -4.56164516,  -4.32662675,  -4.09160833,
#         -3.85658992,  -3.62157151,  -3.3865531 ,  -3.15153469,
#         -2.91651627,  -2.68149786,  -2.44647945,  -2.21146104,
#         -1.97644263,  -1.74142421,  -1.5064058 ,  -1.27138739,
#         -1.03636898,  -0.80135056,  -0.56633215,  -0.33131374,
#         -0.09629533,   0.13872308,   0.3737415 ,   0.60875991,
#          0.84377832,   1.07879673,   1.31381514,   1.54883356,
#          1.78385197,   2.01887038,   2.25388879,   2.4889072 ,
# ...

# %%
sns.kdeplot(dataset)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.rugplot(dataset,color='black')

for bw in np.arange(0.5,2,.25):
    sns.kdeplot(dataset,bw_method=bw,lw=1.8,label=bw)

# %%
'''
# TODO: 

There are a whole bunch of other statistical graphing examples in this lecture which I'm unfamiliar with...

Revisit this section and understand use cases for each of the statistical techniques...

'''
