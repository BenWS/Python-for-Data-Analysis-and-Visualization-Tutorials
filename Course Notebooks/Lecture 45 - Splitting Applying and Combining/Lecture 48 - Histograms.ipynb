# %%
import pandas as pd
import numpy as np
from numpy.random import randn

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
dataset1 = randn(100)

# %%
plt.hist(dataset1)
# Out:
# (array([ 3.,  3.,  8., 10., 14., 24., 16.,  8.,  6.,  8.]),
#  array([-2.23613504, -1.82467033, -1.41320561, -1.00174089, -0.59027617,
#         -0.17881145,  0.23265326,  0.64411798,  1.0555827 ,  1.46704742,
#          1.87851214]),
#  <BarContainer object of 10 artists>)

# %%
dataset2 = randn(80)

plt.hist(dataset2, color='indianred')
# Out:
# (array([ 1.,  2.,  7.,  9., 17., 17.,  9., 13.,  1.,  4.]),
#  array([-2.44143456, -1.96695762, -1.49248069, -1.01800375, -0.54352681,
#         -0.06904987,  0.40542707,  0.87990401,  1.35438095,  1.82885788,
#          2.30333482]),
#  <BarContainer object of 10 artists>)

# %%
# TODO: what is the purpose of the 'normed' argument?

plt.hist(dataset1, density=True, alpha=.5, color='indianred')
plt.hist(dataset2, density=True, alpha=.5, color='blue')
# Out:
# (array([0.0263448, 0.0526896, 0.1844136, 0.2371032, 0.4478616, 0.4478616,
#         0.2371032, 0.3424824, 0.0263448, 0.1053792]),
#  array([-2.44143456, -1.96695762, -1.49248069, -1.01800375, -0.54352681,
#         -0.06904987,  0.40542707,  0.87990401,  1.35438095,  1.82885788,
#          2.30333482]),
#  <BarContainer object of 10 artists>)

# %%
data1 = randn(1000)
data2 = randn(1000)

# %%
sns.jointplot(data1,data2)
# Out:
# C:\Users\Ben\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(data1, data2, kind='hex')
# Out:
# C:\Users\Ben\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
